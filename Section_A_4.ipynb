# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_A_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#it prints star
print(" * ")
#it prints my name
print("Meher Nigar")
#it prints the type of the value
number=1
print(type(number))
# Out:
#  *
# Meher Nigar
# <class 'int'>
