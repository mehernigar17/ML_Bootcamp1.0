# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_B_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
celsius = 22
fahrenheit = (celsius*9/5) +32
kelvin = celsius+273.15
print("celcius",celsius)
print("fahrenhite",fahrenheit)
print("kelvin",kelvin)
