# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/section_F_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers=(10,25,15,40,20)
print("maximum=",max(numbers))
print("minimum=",min(numbers))
print("sum=",sum(numbers))
