# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_E_20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(1,51):
    if i%2!= 0:
        continue
    print(i)
