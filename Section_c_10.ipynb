# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_c_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter number1"))
num2 = float(input("Enter number2"))

print("add",num1+num2)
print("sub",num1-num2)
print("mul",num1*num2)
print("div",num1/num2)
print("floor",num1//num2)
print("mod",num1%num2)
print("expo",num1**num2)
# Out:
# Enter number11
# Enter number22
# add 3.0
# sub -1.0
# mul 2.0
# div 0.5
# floor 0.0
# mod 1.0
# expo 1.0
