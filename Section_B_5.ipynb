# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_B_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name ="Meher Nigar"
age =22
height =5.4
isstudent =True

print("Name-",name,"Type-",type(name))
print("Age-",age,"Type-",type(age))
print("Height-",height,"Type",type(height))
print("StudentStatus-",isstudent,"Type-",type(isstudent))
# Out:
# Name- Meher Nigar Type- <class 'str'>
# Age- 22 Type- <class 'int'>
# Height- 5.4 Type <class 'float'>
# StudentStatus- True Type- <class 'bool'>
