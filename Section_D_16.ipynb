# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_D_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter number"))

if num%2==0:
    if num>100:
        print("number is even and greater than 100")
    else:
        print("the number is  even and less than 100")
else:
    print("number is odd")
