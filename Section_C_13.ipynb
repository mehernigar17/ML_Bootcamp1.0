# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_C_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("enter num"))

if num%3==0 and num%5== 0:
    print("divisibke by 3 and 5")
else:
    print("not divisible by both 3 and 5")
