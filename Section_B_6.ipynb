# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_B_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a =2
b = 5
print("before swap")
print(a)
print(b)
a, b = b, a
print("after swap")
print("a =",a)
print("b =",b)
# Out:
# before swap
# 2
# 5
# after swap
# a = 5
# b = 2
