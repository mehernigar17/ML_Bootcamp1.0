# %% [markdown]
# <a href="https://colab.research.google.com/github/mehernigar17/ML_Bootcamp1.0/blob/main/Section_c_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=int(input("enter number"))

print("and",num>=10 and num<=50)
print("or",num<10 or num>50)
print("not",not(num>=10 and num<=50))
# Out:
# enter number3
# and False
# or True
# not True
